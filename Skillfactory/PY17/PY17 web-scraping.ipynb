# %% [markdown]
# ## МЕТОДЫ ЗАПРОСОВ В ПРОТОКОЛЕ HTTP
#
# Для того чтобы указать серверу на то, какое действие мы хотим произвести с ресурсом, в протоколе HTTP используются так называемые методы. В HTTP существует несколько методов, которые описывают действия с ресурсами. Чаще всего используются GET и POST.
#
# ### GET — ПОЛУЧЕНИЕ РЕСУРСА
#
# Метод GET запрашивает информацию из указанного источника и не может влиять на его содержимое. Запрос доступен для кэширования данных (то есть для сохранения, восстановления и дальнейшего использования) и добавления в закладки. Длина запроса ограничена (максимальная длина — 2048 символов).
#
# Пример GET-запроса, отправляемого через адресную строку браузера:

# %%
# http://site.ru/page.php?name=dima&age=27

# %% [markdown]
# ### POST — СОЗДАНИЕ РЕСУРСА
#
# Метод POST используется для отправки данных, которые могут оказывать влияние на содержимое ресурса. В отличие от метода GET, запросы POST не могут быть кэшированы, они не остаются в истории браузера и их нельзя добавить в закладки. Длина запроса POST не ограничивается.
#
# Пример POST-запроса, отправляемого через форму запроса:

# %%
# POST / HTTP/1.0\r\n
# Host: www.site.ru\r\n
# Referer: http://www.site.ru/index.html\r\n
# Cookie: income=1\r\n
# Content-Type: application/x-www-form-urlencoded\r\n
# Content-Length: 35\r\n
# \r\n
# login=Dima&password=12345

# %% [markdown]
# Как только библиотека установлена, импортируем её и отправим наш первый запрос к ресурсу Курсы валют ЦБ РФ в XML и JSON. Используем метод get() из библиотеки requests, передав ему соответствующий URL —  https://www.cbr-xml-daily.ru/daily_json.js:

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа Response, который содержит всю нужную нам информацию. По умолчанию в квадратных скобках на экран выводится код статуса ответа. В данном случае он равен 200 — то есть запрос был корректным и сервер отдал нам нужную информацию. Значение кода статуса 404 означало бы, что страница по указанному адресу не найдена, а значение 403 — что синтаксис GET-запроса неверный.
#
# Код ответа в виде числовой переменной можно получить с помощью метода status_code:

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %%
# Задание 3.1
# 1 point possible (graded)
# Вы уже импортировали модуль requests в ваш код. Напишите строку кода, при выполнении которой будет сделан GET-запрос к ресурсу 
# https://www.cbr-xml-daily.ru/daily.xml, а результат ответа будет сохранён в переменной response:


import requests # Импортируем библиотеку requests
# url = 'https://www.cbr-xml-daily.ru/daily.xml' # Определяем значение URL страницы для запроса
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js') # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

print(response) # Выводим значение response на экран как объект
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %% [markdown]
# ### РАБОТАЕМ С ОТВЕТОМ
#
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ в XML и JSON.
#
# ?
# Как получить доступ ко всей информации, которую содержит ответ?
#
# Текст ответа хранится в атрибуте text. Выведем значение атрибута на экран и посмотрим на его содерж

# %%
print(response.text)
# Out:
# {
#     "Date": "2022-04-06T11:30:00+03:00",
#     "PreviousDate": "2022-04-05T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/04\/05\/daily_json.js",
#     "Timestamp": "2022-04-05T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 63.4725,
#             "Previous": 62.8119
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 49.0306,
#             "Previous": 49.1725
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 109.3245,
#             "Previous": 109.5907
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 17.3077,
#             "Previous": 17.3017
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 28.3231,
#             "Previous": 28.3607
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 46.9007,
#             "Previous": 47.2358
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 18.0537,
#             "Previous": 17.7941
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 24.6757,
#             "Previous": 24.9868
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 1,
#             "Name": "Гонконгский доллар",
#             "Value": 10.6602,
#             "Previous": 10.6883
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 12.3316,
#             "Previous": 12.4197
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 83.352,
#             "Previous": 83.5932
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 91.7289,
#             "Previous": 92.3872
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 10,
#             "Name": "Индийских рупий",
#             "Value": 10.9713,
#             "Previous": 10.9621
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.6309,
#             "Previous": 17.6894
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 66.735,
#             "Previous": 66.8104
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 97.2602,
#             "Previous": 97.4658
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 13.0993,
#             "Previous": 13.1372
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 45.4745,
#             "Previous": 45.5618
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 96.062,
#             "Previous": 95.6116
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 19.7129,
#             "Previous": 19.8644
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 18.5148,
#             "Previous": 18.628
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 114.7732,
#             "Previous": 115.1053
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 61.4373,
#             "Previous": 61.5924
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 66.6816,
#             "Previous": 66.8746
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 56.6681,
#             "Previous": 56.8681
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 23.8149,
#             "Previous": 23.8838
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 73.0613,
#             "Previous": 73.2977
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 28.351,
#             "Previous": 28.3624
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 37.5612,
#             "Previous": 37.8267
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 88.6733,
#             "Previous": 89.1271
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 89.9741,
#             "Previous": 90.1761
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 57.3221,
#             "Previous": 57.3192
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 68.7326,
#             "Previous": 68.835
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 68.0147,
#             "Previous": 68.2784
#         }
#     }
# }

# %%
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь.
# В объект ответа Response  из библиотеки requests уже встроен метод json() .
# Импортируем функцию pprint(), применим к полученному ответу метод json() и выведем полученный результат на экран:

from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-04-06T11:30:00+03:00',
#  'PreviousDate': '2022-04-05T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/04/05/daily_json.js',
#  'Timestamp': '2022-04-05T23:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 17.3017,
#                     'Value': 17.3077},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 62.8119,
#                     'Value': 63.4725},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 49.1725,
#                     'Value': 49.0306},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 47.2358,
#                     'Value': 46.9007},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 17.7941,
#                     'Value': 18.0537},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 28.3607,
#                     'Value': 28.3231},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 66.8104,
#                     'Value': 66.735},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 90.1761,
#                     'Value': 89.9741},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 13.1372,
#                     'Value': 13.0993},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 37.8267,
#                     'Value': 37.5612},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 12.4197,
#                     'Value': 12.3316},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 92.3872,
#                     'Value': 91.7289},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 109.5907,
#                     'Value': 109.3245},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 10.6883,
#                     'Value': 10.6602},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 24.9868,
#                     'Value': 24.6757},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 10.9621,
#                     'Value': 10.9713},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 68.2784,
#                     'Value': 68.0147},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 97.4658,
#                     'Value': 97.2602},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 68.835,
#                     'Value': 68.7326},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 17.6894,
#                     'Value': 17.6309},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 45.5618,
#                     'Value': 45.4745},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 95.6116,
#                     'Value': 96.062},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 19.8644,
#                     'Value': 19.7129},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 18.628,
#                     'Value': 18.5148},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 89.1271,
#                     'Value': 88.6733},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 61.5924,
#                     'Value': 61.4373},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 66.8746,
#                     'Value': 66.6816},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 23.8838,
#                     'Value': 23.8149},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 56.8681,
#                     'Value': 56.6681},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 28.3624,
#                     'Value': 28.351},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 83.5932,
#                     'Value': 83.352},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 73.2977,
#                     'Value': 73.0613},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 115.1053,
#                     'Value': 114.7732},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 57.3192,
#                     'Value': 57.3221}}}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ### ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ
#
# Получим HTML-код интересующей нас страницы.
#
# Для этого отправим GET-запрос с помощью библиотеки requests и метода get() и посмотрим на текст ответа на наш запрос (как мы помним, он содержится в атрибуте text):

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!doctype html>
# <html class="old-town-road no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#     <link rel="icon" href="/i/favicon-bw.png" />
#
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#         <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1649061972">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#     <link rel="stylesheet" href="/js/tests/scopus/css/style.css">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">
#             Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)
#     </div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2022/03/31/please-to-meet-me" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/31/please-to-meet-me" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Билл Салливан &laquo;Познакомьтесь с собой. Как гены, микробы и нейроны делают нас теми, кто мы есть&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/29/origins" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Льюис Дартнелл &laquo;Происхождение. Как Земля создала нас&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/25/stranger-than-we-can-imagine" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Джон Хиггс &laquo;Все страньше и страньше&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/23/close-encounters-with-humankind" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Санхи Ли &laquo;Близкие контакты далеких предков: Как эволюционировал наш вид&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/21/swallow-this" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Джоанна Блайтмэн &laquo;По косточкам. Разделываем пищевую индустрию на части&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/17/sincerity-after-communism" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Эллен Руттен &laquo;Искренность после коммунизма: культурная история&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/16/what-does-rain-smell-like" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Саймон Кинг, Клэр Насир &laquo;Чем пахнет дождь?&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/14/geneweap" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Из пушки по генам: что не так с &laquo;этнически ориентированным&raquo; оружием</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/10/microbes" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Экстренное уничтожение: от каких бактерий избавлялись в украинских лабораториях</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2022/04/05/junkyard-planet" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>Адам Минтер &laquo;Планета свалок: Путешествия по многомиллиардной индустрии мусора&raquo;</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>
# <script type="text/insert-source" data-type="inserts.gallery.page">{"id":28572,"type":3,"text":"","img":[{"src":"https:\/\/nplus1.ru\/images\/2021\/10\/11\/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg","alt":"Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.","credits":"Niklas Elmehed © Nobel Prize Outreach"}],"id_news":30917,"title":null,"vtitle":"","vsrc":"","vcredits":"","points":"[]","votes":0,"updated_at":"2021-10-11 13:10:06"}</script>
# Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/nica-full-injection" data-id="32702" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2022/04/05/52b63323e8f1488617ce19e7af235ecc.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2022-04-05">вчера</span>
#                         </div>
#                         <h3>На ускорительном комплексе NICA впервые одновременно заработали &laquo;Бустер&raquo; и&nbsp;&laquo;Нуклотрон&raquo;</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/covid-vaccines-save-fetus" data-id="32701" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-04-05">вчера</span>
#                 </div>
#
#                                     <h3>Вакцинация от ковида не привела к врожденным аномалиям плода</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/Modulated-Thermal-Convection" data-id="32697" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-04-05">вчера</span>
#                 </div>
#
#                                     <h3>Модуляция градиента температуры увеличила теплопередачу в газе</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/amargasaurus-sail" data-id="32692" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-04-05">вчера</span>
#                 </div>
#
#                                     <h3>Палеонтологи подтвердили наличие шейного паруса у родича диплодока</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/cocrystal-photocarving" data-id="32696" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-04-05">вчера</span>
#                 </div>
#
#                                     <h3>Лазер небольшой мощности разрезал сокристалл</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/he-unchained" data-id="32698" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/04/05/6313117064b49709940558c05d4e2b55.jpg)" class="ill"></div>
#
#
#
#                                     <h3>&laquo;Создатель&raquo; ГМ-детей Хэ Цзянькуй вышел из тюрьмы</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/05/amargasaurus-sail" data-id="32692" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/04/04/f67cfba5200bed553250fc4b1fc77ba8.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Палеонтологи подтвердили наличие шейного паруса у родича диплодока</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/04/04/tyrannosaurus-arms" data-id="32686" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/04/04/ecdc442f2401a758224d004b7776dc41.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Уменьшение передних лап тираннозаврид объяснили защитой от укусов сородичей</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2022/03/05/076dc31136a94b857123c6e497b8a4ec.jpg" style=background-image:url(https://nplus1.ru/images/2022/03/05/a59c304cc22c907285e3dad3347a8b74.jpg)>
#
#     <a href="/material/2022/04/04/pain" data-id="32463" >
#         <div class="caption">
#                                                                                     <h3>Просто больно</h3>
#                     <p class="subtitle">Как устроена боль и может ли она быть беспричинной</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/medicine">Медицина</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="zsMRPFlZrtaFrEngbBgI1Dr15Yox94EVtKYu020F">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="zsMRPFlZrtaFrEngbBgI1Dr15Yox94EVtKYu020F">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/29/mechanical-coherence">Время когерентности механического колебания превысило сто миллисекунд</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/04/04/K-He3-spins">Магнитное поле сделало спин-обменную связь между калием и гелием сильной</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/04/05/Modulated-Thermal-Convection">Модуляция градиента температуры увеличила теплопередачу в газе</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2022/03/28/tinkoff-analytics-2">От простого к сложному</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/30/hybrid-opticalmicrowave">Циркулярными ридберговскими состояниями научились управлять с помощью света</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/04/04/white-phosphorus-functionalization">Химики нашли удобный способ окисления белого фосфора</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2022/04/04/pain">Просто больно</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/31/atom-light-beam">Смесь атомов и света поможет сфокусировать лазер на световом парусе</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/04/01/Laozi-said-nothing-wrong">Физики разобрались с точением камня водой</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/31/human-genome-full">Опубликована полная последовательность человеческого генома</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/blog/2022/04/01/samotek">Авторам</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2022 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                                         <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <script src="/js/tests/scopus/js/bundle.js"></script>
#
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1643976149"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\denis.kozarenko\appdata\local\programs\python\python39\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\denis.kozarenko\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %% [markdown]
# Ранее мы уже получили содержимое страницы с помощью GET-запроса и сохранили информацию в переменной response , теперь создадим объект BeautifulSoup с именем page, указывая в качестве параметра html.parser.
#
# Для примера получим информацию o title (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ### ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ
#
# Выполним поставленную ранее задачу: получить информацию о странице и извлечь заголовок статьи, опубликованной на этой странице, дату публикации, а также текст статьи.
#
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён в тег <h1> … </h1> (заголовок первого уровня).
#
# Тогда мы можем получить его текст с помощью метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
print(page.find('time').text) # Выводим на экран содержимое атрибута text тега time
# Out:
# 13:04
# 11 Окт. 2021

# %%
# Задание 5.4
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.

def wiki_header(url_string):
    import requests # Импортируем библиотеку requests
    from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
    url = url_string # Определяем адрес страницы
    response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
    page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
    return page.find('h1').text

url = 'https://en.wikipedia.org/wiki/Operating_system'
print(wiki_header(url))
# Out:
# Operating system

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %%
# Дело в том, что теги <div> … </div> очень распространённые и на странице их очень много. Метод find() нашёл первый из них, но это не то, что нам надо.
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, что у искомого текста есть свой класс — body js-mediator-article :
# Передадим название класса в метод find() с помощью аргумента class_ и получим текст статьи:

print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article

# %% [markdown]
# ### СБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег <a> … </a>. Попробуем использовать find():

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %%
# Мы получили только одну ссылку, хотя на странице их явно больше.
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 937

# %%
# Итак, на момент создания этих учебных материалов на странице содержалось 928 ссылок. Посмотрим на некоторые из них:
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Opal', 'Open Programming Language', 'OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OPS5', 'OptimJ', 'Orc', 'ORCA/Modula-2', 'Oriel']

# %%
# Не все ссылки соответствуют названиям языков программирования — страница содержит также «служебные» ссылки, такие, например, как Jump to navigation (с англ. Перейти к навигации) или Alphabetical (с англ. По алфавиту):
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %%
TOKEN = '6004213060042130600421302260782650660046004213002490b972779857192726489'
http_string ='https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token='
url = http_string + TOKEN
response = requests.get(url) # Делаем GET-запрос к ресурсу
response.text
# Out:
# '{"response":[{"id":1,"first_name":"Pavel","last_name":"Durov","can_access_closed":true,"is_closed":false}]}'

# %%
http_string ='https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token='
url = http_string + TOKEN
response = requests.get(url) # Делаем GET-запрос к ресурсу
response.text
# Out:
# '{"response":[{"id":1,"first_name":"Pavel","last_name":"Durov","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}'

# %%
# ЗАПРОС К API ИЗ КОДА
# Продолжаем пользоваться всё той же библиотекой requests.
import requests # Импортируем модуль requests
token = '6004213060042130600421302260782650660046004213002490b972779857192726489' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}

# %%
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
ids = ",".join(map(str, range(1, 500))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
users = requests.get(url, params=params).json() # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()

# %%
import json # Импортируем модуль json
from pprint import pprint # Импортируем функцию pprint()
import pandas as pd # Импортируем модуль pandas
from IPython.display import display
# pprint(users)
df = pd.DataFrame(users['response']) # Создаём объект DataFrame из списка recipes
display(df.head()) # Выводим на экран первые строки полученного DataFra(users)

mask_sex = df['sex'] != 0
display(round(df[mask_sex]['sex'].value_counts(normalize=True), 2))
# Out:
#    id  first_name    last_name can_access_closed is_closed  sex       bdate  \
# 0   1       Павел        Дуров              True     False    2  10.10.1984
# 1   2  Александра  Владимирова             False      True    1         NaN
# 2   3     DELETED                            NaN       NaN    0         NaN
# 3   4     DELETED                            NaN       NaN    0         NaN
# 4   5        Илья  Перекопский              True     False    2       18.11
#
#   deactivated
# 0         NaN
# 1         NaN
# 2     deleted
# 3     deleted
# 4         NaN
# 2    0.51
# 1    0.49
# Name: sex, dtype: float64

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
import requests # Импортируем модуль requests

url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
# print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
len(data['response']['items'])
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
max_count = data['response']['count']
max_count
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]
# 12466983

# %%
import requests # Импортируем модуль requests

url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 10 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 10 пользователей с offset = 0
# Выгружаю 10 пользователей с offset = 10
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# ### ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ
#
# → В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = '6004213060042130600421302260782650660046004213002490b972779857192726489' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    # pprint(response.text)
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 

print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ### ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ
#
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = '6004213060042130600421302260782650660046004213002490b972779857192726489' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 480,
#               'items': [{'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd152e471225c7a530f',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1648630509,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239598,
#                                                     'owner_id': -139533130,
#                                                     'photo_1280': 'https://sun1-86.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=1280x720&quality=96&sign=68b66066fbfc2016cbf42fc47ec28633&c_uniq_tag=5ta-irADHlhDJ2XyHG-7Zto1aI9ZsD17dJshysww2RY&type=video_thumb',
#                                                     'photo_130': 'https://sun1-86.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=39fe497c3ab4f040bbcc73f0f441205d&c_uniq_tag=hIAv1yFUpn9r_qo8BthRNc3A-cevMkbMCO_OPch7QOg&type=video_thumb',
#                                                     'photo_320': 'https://sun1-86.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=9773fba63f698c3ebea0e9024350af58&c_uniq_tag=chvD9WFMDo1mBwE6qHeUY5373-0lSYxZjl5c0Fvkn1g&type=video_thumb',
#                                                     'photo_800': 'https://sun1-86.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=ed7577955480c0d8c0cd6a50f46b65ee&c_uniq_tag=4-_zWmEATvr9Bwhiwes7xSgywKKUzdaYsGgOtksmuJg&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Создавать '
#                                                              'истории — просто',
#                                                     'track_code': 'video_e98a5c200c6XTWaGZNAJKyaCm9GdLbEi_9ru5y2pWZ_RAROsOZ_r6IhPZYoO0ggiLIv20qgbgxHG79ffKd44870B',
#                                                     'views': 66819,
#                                                     'width': 1920}},
#                                          {'type': 'video',
#                                           'video': {'access_key': '2016c91ffaa91419bb',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments':
#                                                     'photo_800': 'https://sun1-24.userapi.com/impf/yi3_EkVgac7lMzdqvHrusW5JdIG8GEWw-SYvFg/YURlBbVUwic.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=d0292bea29132d1e6a5d54cb16191db9&c_uniq_tag=nrrKWrwUiTZRCa7J5w-P517EBTLKeIRpp_53SmnInAo&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Как создать '
#                                                              'сообщество '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_2174fa32oyAAxuKqPgivRUg1HUeceEwvzVnGsE-WTPVqeYblySuTAR7D7s0_CqRKQ1wZcqpKfxb-af-0OPcgmWo',
#                                                     'views': 223849,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 137,
#                                       'groups_can_post': True},
#                          'date': 1648803000,
#                          'from_id': -22822305,
#                          'hash': 'hrf3WrF0ffsdvK6r3g',
#                          'id': 1289260,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 612,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 150, 'user_reposted': 0},
#                          'text': 'Весной пользователи стали создавать на 369% '
#                                  'больше новых сообществ. Нам приходит всё '
#                                  'больше вопросов — о продвижении, '
#                                  'монетизации, правилах ведения пабликов.\n'
#                                  '\n'
#                                  'Как создать своё сообщество, показываем на '
#                                  'видео. Как развивать свой паблик, '
#                                  'рассказываем в этой '
#                                  '[vk.com/@authors-kak-razvivat-soobschestvo-vkontakte|статье]. '
#                                  'А как начать бизнес ВКонтакте, подробно '
#                                  'объясняем '
#                                  '[vk.com/@business-dlya-novichkov|здесь].',
#                          'views': {'count': 212422}},
#                         {'attachments': [{'link': {'button': {'action': {'type': 'open_url',
#                                                                          'url': 'https://vk.com/blog/video-tv'},
#                                                               'title': 'Read'},
#                                                    'caption': 'vk.com',
#                                                    'description': 'Показываем '
#                                                                   'все '
#                                                                   'возможности '
#                                                                   'платформы и '
#                                                                   'классные '
#                                                                   'уголки '
#                                                                   'видеобиблиотеки '
#                                                                   '— в '
#                                                                   'путеводителе '
#                                                                   'по '
#                                                                   'крупнейшему '
#                                                                   'видеосервису '
#                                                                   'в России.',
#                                                    'photo': {'album_id': -1,
#                                                              'date': 1648209389,
#                                                              'id': 461982783,
#                                                              'owner_id': 100,
#                                                              'sizes': [{'height': 72,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun1-87.userapi.com/impf/CguuOMP9I90f_pYv2kf4OECLtq4x2wh5DxJPtw/zX-WCu9TBXc.jpg?size=130x72&quality=96&sign=9b4f0588da1e7d5703e19250bbbb3373&c_uniq_tag=BF8L6iEtzhtSMqdJDLCIygdKTBI6T0SRS808TB7lCw0&type=album',
#                                                                         'width': 130},
#                                                                        {'height': 87,
#                                                                         'type': 'o',
#                                                                         'url': 'https://sun1-87.userapi.com/impf/CguuOMP9I90f_pYv2kf4OECLtq4x2wh5DxJPtw/zX-WCu9TBXc.jpg?size=130x87&quality=96&crop=135,0,1282,858&sign=c1414a823e8798f7a3cf262777b30b82&c_uniq_tag=xmq6uYxiwh7ekb4imTghxKaYivl5Pv4vr0URYyFYh8U&type=album',
#                                                                         'width': 130},
#                                                                        {'height': 133,
#                                                                         'type': 'p',
},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'da6527a3bcf8cfe7ad',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1648114992,
#                                                     'description': '',
#                                                     'duration': 17,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456241736,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_x',
#                                                     'repeat': 1,
#                                                     'title': 'VK Видео на '
#                                                              'Smart TV',
#                                                     'track_code': 'video_81032adeFCvliE1lhEmGK0Ijsb365rB85dSzI6dGQ9Y9w8j-6RgkCvuKSgKHSY0tQU6xiMzUhE3S54Un0Ccvuj0',
#                                                     'views': 361254,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 521,
#                                       'groups_can_post': True},
#                          'date': 1648119076,
#                          'from_id': -22822305,
#                          'hash': 'glCGKxuz-VPp5T305A',
#                          'id': 1286624,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1354,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 523, 'user_reposted': 0},
#                          'text': 'Запустили приложение VK Видео для Smart '
#                                  'TV. \n'
#                                  'Смотреть можно бесплатно и без авторизации '
#                                  'ВКонтакте.\n'
#                                  '\n'
#                                  'На выбор — фильмы и сериалы, блоги и мемы, '
#                                  'игровые стримы и спортивные трансляции. А '
#                                  'если зайдёте в аккаунт, то увидите свои '
#                                  'плейлисты и персональные рекомендации. Все '
#                                  'наши фишки на месте: поддерживаем разрешение '
#                                  'до Full HD и 4К, а старые ролики улучшаем с '
#                                  'помощью технологии NeuroHD. \n'
#                                  '\n'
#                                  'Приложение уже доступно на телевизорах '
#                                  'Samsung, LG и устройствах с Android TV, а '
#                                  'скоро выйдет и на Apple TV. Следите за '
#                                  'новостями и открывайте инструкцию по '
#                                  'установке в сообществе [club207536086|VK '
#                                  'Видео].',
#                          'views': {'count': 393655}},
#                         {'attachments': [{'photo': {'access_key': 'f77c5e0db3805c9a9e',
#                                                     'album_id': -7,
#                                                     'date': 1648041889,
#                                                     'id': 457330266,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 
#                                  'Делитесь самыми ценными воспоминаниями в '
#                                  'историях — и отмечайте тех, кому они тоже '
#                                  'важны. Это можно сделать в мобильном '
#                                  'приложении.\n'
#                                  '\n'
#                                  'Новый раздел появился в профиле: в версии '
#                                  'для компьютера — под аватаром, в мобильной '
#                                  'версии — в разделе «Другое», в мобильном '
#                                  'приложении VK — в трёх точках. Попасть в '
#                                  '«Воспоминания» также можно по прямой ссылке: '
#                                  'vk.com/memories',
#                          'views': {'count': 1904651}}]}}

# %%
# Анализируя ответ, понимаем, что по ключу count можно найти общее количество сообщений в новостной ленте, а по ключу items — сами сообщения.
# Посмотрим на информацию об отдельном сообщении:

response.json()['response']['items'][5]
# Out:
# {'id': 1286624,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1648119076,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'Запустили приложение VK Видео для Smart TV. \nСмотреть можно бесплатно и без авторизации ВКонтакте.\n\nНа выбор — фильмы и сериалы, блоги и мемы, игровые стримы и спортивные трансляции. А если зайдёте в аккаунт, то увидите свои плейлисты и персональные рекомендации. Все наши фишки на месте: поддерживаем разрешение до Full HD и 4К, а старые ролики улучшаем с помощью технологии NeuroHD. \n\nПриложение уже доступно на телевизорах Samsung, LG и устройствах с Android TV, а скоро выйдет и на Apple TV. Следите за новостями и открывайте инструкцию по установке в сообществе [club207536086|VK Видео].',
#  'attachments': [{'type': 'video',
#    'video': {'access_key': 'da6527a3bcf8cfe7ad',
#     'can_comment': 0,
#     'can_like': 1,
#     'can_repost': 1,
#     'can_subscribe': 1,
#     'can_add_to_faves': 1,
#     'can_add': 1,
#     'comments': 0,
#     'date': 1648114992,
#     'description': '',
#     'duration': 17,
#     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_s',
#     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_l',
#     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_x',
#     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=9&type=39&tkn=rXXsX6dAQ5E9a_gAdyhx_IQerVw&fn=vid_w',
#     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_sm',
#     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_d',
#     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_md',
#     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI&fn=vid_f',
#     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2308967303785&idx=0&type=39&tkn=152ozaAhiLbgNeiHcIjzKRg1ATI',
#     'width': 1920,
#     'height': 1080,
#     'id': 456241736,
#     'owner_id': -22822305,
#     'title': 'VK Видео на Smart TV',
#     'track_code': 'video_81032adeFCvliE1lhEmGK0Ijsb365rB85dSzI6dGQ9Y9w8j-6RgkCvuKSgKHSY0tQU6xiMzUhE3S54Un0Ccvuj0',
#     'repeat': 1,
#     'views': 361254}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 521, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 1354, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 523, 'user_reposted': 0},
#  'views': {'count': 393655},
#  'hash': 'glCGKxuz-VPp5T305A'}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.
#
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'Аудитория ВКонтакте растёт: в ': [383, 1041, 252, 1648644620],
#  'В личном кабинете VK ID появил': [396, 1359, 386, 1647352647],
#  'В этом месяце пользователи ВКо': [359, 1036, 182, 1648885800],
#  'ВКонтакте вы всегда можете защ': [1998, 1557, 681, 1647437245],
#  'ВКонтакте отмечен рекордный ро': [518, 1955, 391, 1648051080],
#  'Весной пользователи стали созд': [137, 612, 150, 1648803000],
#  'Впервые ВКонтакте, давно не за': [248, 1379, 344, 1648035738],
#  'Запустили приложение VK Видео ': [521, 1354, 523, 1648119076],
#  'Подсчитали: просмотры историй ': [817, 677, 209, 1648975800],
#  'Что посмотреть ВКонтакте? [htt': [373, 449, 78, 1648715757]}

# %% [markdown]
# ДОПОЛНИТЕЛЬНО
#
# Если вы размещаете рекламу во ВКонтакте, то можно выгружать всю статистику через ads API(https://vk.com/dev/ads).
#
# Полный список методов ВКонтакте можно посмотреть в документации.(https://vk.com/dev/methods)

# %% [markdown]
# ### КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК
#
# Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют задачей (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль schedule (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль schedule не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %%
# Устанавливаем библиотеку schedule
# %pip3 install schedule 
# Для того чтобы у нас появилась возможность использовать модуль в коде, импортируем его:

import schedule # Импортируем модуль schedule
# Out:
# UsageError: Line magic function `%pip3` not found.

# %%
# import schedule

# def task(): 
#     print('Hello! I am a task!') 
#     return

# schedule.every(2).minutes.do(task)

# import time 
# while True: 
#     schedule.run_pending() 
#     time.sleep(1)

# %%
class sample:
    pass
test=sample()
test.name="test1"
print(test.name)
# Out:
# test1

# %%
print(list(zip([1,2,3], ['apple', 'grape', 'orange'], ['x', 2, True])))

for num, fruit, thing in zip([1,2,3], ['apple', 'grape', 'orange'], ['x', 2, True]):
    print(num)
    print(fruit)
    print(thing)
# Out:
# [(1, 'apple', 'x'), (2, 'grape', 2), (3, 'orange', True)]
# 1
# apple
# x
# 2
# grape
# 2
# 3
# orange
# True

# %% [markdown]
# ВЫПОЛНЕНИЕ ФУНКЦИИ
#
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:

# %%
a = '1'
b = '2'
c = '3'
s = a + '[' + b + ':' + c + ']'
print(s)
# Out:
# 1[2:3]

# %%
#Пример *args
def sample(*args):
    print(args)

sample('time', 1, True)

#Пример **kwargs
def sample(**kwargs):
    print(kwargs)

sample(a = 'time', b = 1)
# Out:
# ('time', 1, True)
# {'a': 'time', 'b': 1}

# %%
def star_triangle(r):
   for x in range(r):
      print(' '*(r-x-1)+'*'*(2*x+1))

star_triangle(7)
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************

# %%
a = [1,2,3]
b = a
c = [1,2,3]
print(a == b, a == c, a is b, a is c)
# Out:
# True True True False

# %%
def apply_discounts(products, stocks):
    """
    Напишите функцию apply_discounts(), которая снижает цену продуктов в словаре products на указанный в словаре stocks процент. 
    Функция должна вернуть результирующий словарь, ключи которого — товары, а значения — новые цены.
    Если продукта из словаря stocks нет в словаре products, то его необходимо пропустить. Цены округлите до второго знака после запятой.
    """
    for product, price in products.items():
        for stock, discount in stocks.items():
            if product == stock:
                products[product] = round(price * (1 - float(discount.replace('%' , ''))/100), 2)
    return products


    
if __name__ == '__main__':
    products={
        "Oranges (packaged)": 114.99, 
        "Candy (Rotfront)": 280.00,
        "Boiled sausage": 199.99,
        "Juice J7 (orange)": 119.99,
        "Trout (Seven Seas)": 399.99
        }
    stocks = {
        "Boiled sausage": "33%",
        "Juice J7 (orange)": "12%",
        "Trout (Seven Seas)": "18%"
    }
    new_products = apply_discounts(products, stocks)
    print(new_products)
# Out:
# {'Oranges (packaged)': 114.99, 'Candy (Rotfront)': 280.0, 'Boiled sausage': 133.99, 'Juice J7 (orange)': 105.59, 'Trout (Seven Seas)': 327.99}

# %%
import pandas is pd
ttt = pd.Da
